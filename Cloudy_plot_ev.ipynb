# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import os

# Changes directory to access the Python packages
os.chdir('/home/hina0830/Research/CRESST/Cloudy/packages')

import Continuum_keV as cont
from IPython.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))

# %load_ext autoreload
# %autoreload 2
# Out:
# <style>.container { width:80% !important; }</style>
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
os.chdir('/home/hina0830/Research/CRESST/Cloudy')
path = 'AGN_0607'
fname = 'test2test2_ev.txt'
result = pd.read_csv(path + '/' + fname)
print(len(result))
# Out:
# 8228

# %%
path = 'AGN_0707'
name1 = 'AGN0.5'
name2 = 'AGN1.0'
name3 = 'AGN1.5'
prefix = 'default AGN'
name_index  = {0:'a(x)=-0.5', 1:'a(x)=-1.0', 2:'a(x)=-1.5'}

# %%
columns = ['#Cont  nu', 'incident', 'trans', 'DiffOut', 'net trans', 'reflec', 'total', 'reflin', 'outlin', 'lineID', 'cont', 'nLine']

# %%
name_index  = {0:'a(x)=-0.5', 1:'a(x)=-1.0', 2:'a(x)=-1.5', 3:'generic AGN'}

# %%
name_index[3]
# Out:
# 'generic AGN'

# %%
#file = open('AGN_0607/test2test2_ev.txt')
file = open(path + '/' + name1 + '_out_ev.txt' )
file.readline()
Cont_nu, incident, trans, DiffOut, net_trans, reflec, total, reflin, outlin, lineID, cont, nLine = np.array([]),np.array([]),np.array([]),np.array([]),np.array([]),np.array([]),np.array([]),np.array([]),np.array([]),np.array([]),np.array([]),np.array([])
for line in file:
    line = line.rstrip('\n')
    line = line.split('\t')
    Cont_nu = np.append(Cont_nu, float(line[0]))
    incident = np.append(incident, float(line[1]))
    trans = np.append(trans, float(line[2]))
    DiffOut = np.append(DiffOut, float(line[3]))
    net_trans = np.append(net_trans, float(line[4]))
    reflec = np.append(DiffOut, float(line[5]))
    total = np.append(total, float(line[6]))
    reflin = np.append(reflin, float(line[7]))
    outlin = np.append(outlin, float(line[8]))
    lineID = np.append(lineID, line[9])
    cont = np.append(cont, line[10])
    nLine = np.append(nLine, float(line[11]))

Cont_nu1, incident1 = Cont_nu/13.6, incident

# %%
fig, ax = plt.subplots(figsize=(8, 6))
ax.set(title='incident continuum vs energy  (a(x)=-1.0) ', xlabel='energy [kev]', ylabel='$\\nu$ $L_{\\nu} $ [erg $s^{-1}$ ]')
plt.title('incident continuum vs energy  (a(x)=-1.0) ', fontsize=18)
plt.xlabel('energy [keV]', fontsize=18)
plt.ylabel('$\\nu$ $L_{\\nu} $ [erg $s^{-1}$ ]', fontsize=18)

plt.plot( Cont_nu/13.6, incident)
#plt.scatter(Cont_nu[n]/13.6, incident[n])
#plt.text(Cont_nu[n]/1e6, incident[n], str(Cont_nu[n]/1e6) + ',' + str(incident[n]))
ax.tick_params(axis='x', labelsize= 18) 
ax.tick_params(axis='y', labelsize= 18)
plt.xlim(1e-3, 1e6)
plt.ylim(1e-4, 1e2)
plt.xscale('log')
plt.yscale('log')

# %%
#file = open('AGN_0607/test2test2_ev.txt')
file = open(path + '/' + name2 + '_out_ev.txt' )
file.readline()
Cont_nu, incident, trans, DiffOut, net_trans, reflec, total, reflin, outlin, lineID, cont, nLine = np.array([]),np.array([]),np.array([]),np.array([]),np.array([]),np.array([]),np.array([]),np.array([]),np.array([]),np.array([]),np.array([]),np.array([])
for line in file:
    line = line.rstrip('\n')
    line = line.split('\t')
    Cont_nu = np.append(Cont_nu, float(line[0]))
    incident = np.append(incident, float(line[1]))
    trans = np.append(trans, float(line[2]))
    DiffOut = np.append(DiffOut, float(line[3]))
    net_trans = np.append(net_trans, float(line[4]))
    reflec = np.append(DiffOut, float(line[5]))
    total = np.append(total, float(line[6]))
    reflin = np.append(reflin, float(line[7]))
    outlin = np.append(outlin, float(line[8]))
    lineID = np.append(lineID, line[9])
    cont = np.append(cont, line[10])
    nLine = np.append(nLine, float(line[11]))

Cont_nu2, incident2 = Cont_nu/13.6, incident

# %%
#file = open('AGN_0607/test2test2_ev.txt')
file = open(path + '/' + name3 + '_out_ev.txt' )
file.readline()
Cont_nu, incident, trans, DiffOut, net_trans, reflec, total, reflin, outlin, lineID, cont, nLine = np.array([]),np.array([]),np.array([]),np.array([]),np.array([]),np.array([]),np.array([]),np.array([]),np.array([]),np.array([]),np.array([]),np.array([])
for line in file:
    line = line.rstrip('\n')
    line = line.split('\t')
    Cont_nu = np.append(Cont_nu, float(line[0]))
    incident = np.append(incident, float(line[1]))
    trans = np.append(trans, float(line[2]))
    DiffOut = np.append(DiffOut, float(line[3]))
    net_trans = np.append(net_trans, float(line[4]))
    reflec = np.append(DiffOut, float(line[5]))
    total = np.append(total, float(line[6]))
    reflin = np.append(reflin, float(line[7]))
    outlin = np.append(outlin, float(line[8]))
    lineID = np.append(lineID, line[9])
    cont = np.append(cont, line[10])
    nLine = np.append(nLine, float(line[11]))

Cont_nu3, incident3 = Cont_nu/13.6, incident

# %%
fig, ax = plt.subplots(figsize=(8, 6))

# Plots the incident continuum as a function of energy for 3 simulation results
# at fixed ionization parameter xi=1.5; we varied one of the simulation parameters
# a(x) to go from -1.5~-0.5

ax.tick_params(axis='x', labelsize= 18) 
ax.tick_params(axis='y', labelsize= 18)
plt.title(str(name_index[3]) + " incident continuum vs energy at $\\xi$=1.5", fontsize=18)
plt.xlabel('log$_{10}$(E/[KeV])', fontsize=18)
plt.ylabel('log$_{10}(4\pi \\nu$ $J_{\\nu} $/[erg $cm^{-2} s^{-1}$ ])', fontsize=18)

plt.plot(np.log10(Cont_nu1), np.log10(incident1), label='a(x)=-0.5', linewidth=3)
plt.plot(np.log10(Cont_nu2), np.log10(incident2), label='a(x)=-1.0', linewidth=3)
plt.plot(np.log10(Cont_nu3), np.log10(incident3), label='a(x)=-1.5', linewidth=3)

plt.xlim(-3, 6)
plt.ylim(-4, 2)

plt.legend(fontsize = 18, frameon=False)
# Out:
# /tmp/ipykernel_2132/679203164.py:13: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(np.log10(Cont_nu1), np.log10(incident1), label='a(x)=-0.5', linewidth=3)
# /tmp/ipykernel_2132/679203164.py:14: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(np.log10(Cont_nu2), np.log10(incident2), label='a(x)=-1.0', linewidth=3)
# /tmp/ipykernel_2132/679203164.py:15: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(np.log10(Cont_nu3), np.log10(incident3), label='a(x)=-1.5', linewidth=3)

# %%
columns = ['#Cont  nu', 'incident', 'trans', 'DiffOut', 'net trans', 'reflec', 'total', 'reflin', 'outlin', 'lineID', 'cont', 'nLine']

# %%
path = 'AGN_0725'
name1 = 'Mrk509_n1'
name2 = 'Mrk509_n5'
name3 = 'Mrk509_n10'
prefix = 'Mrk509'
name_index  = {0:'$n_H$=1', 1:'$n_H$=5', 2:'$n_H$=10', 3:'Mrk509'}

# %%
os.chdir('/home/hina0830/Research/CRESST/Cloudy')

# %%
# Reads the files and create arrays of informations
Cont_nu1, incident1, total1, trans1 = cont.incident(path, name1)
Cont_nu2, incident2, total2, trans2 = cont.incident(path, name2)
Cont_nu3, incident3, total3, trans3 = cont.incident(path, name3)

# %%
file = open('AGN_0726' + '/' + 'AGN_xi2' + '_out_ang.txt' )
file.readline()
Cont_nu, incident, trans, DiffOut, net_trans, reflec, total, reflin, outlin, lineID, cont, nLine = np.array([]),np.array([]),np.array([]),np.array([]),np.array([]),np.array([]),np.array([]),np.array([]),np.array([]),np.array([]),np.array([]),np.array([])
for line in file:
    line = line.rstrip('\n')
    line = line.split('\t')
    Cont_nu = np.append(Cont_nu, float(line[0]))
    trans = np.append(trans, float(line[1]))

# %%
# Plots the absorption lines of the gas near galaxy Markarian 509
fig, ax = plt.subplots(figsize=(16,3))
plt.title(str(name_index[3]) + " absorption lines (transmitted) at $\\xi$=2", fontsize=18)

plt.title('transmittance vs wavelength at $\\xi$=2', fontsize=18)
plt.xlabel('wavelength [$\AA$]', fontsize=18)
plt.ylabel('transmitted/incident', fontsize=18)
ax.tick_params(axis='x', labelsize= 18) 
ax.tick_params(axis='y', labelsize= 18)
plt.plot(Cont_nu, trans)
plt.xlim(1, 20)
# Out:
# (1.0, 20.0)
